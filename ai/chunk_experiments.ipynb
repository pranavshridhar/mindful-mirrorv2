# %%
reddit_sample = """Two years ago, I made the hardest, most soul-shattering decision of my life: I left my wife. Not because I stopped loving her or because we grew apart. I walked away because I couldn’t keep tearing myself apart, trying to be someone I wasn’t, to fit into a life that felt like it was slowly strangling me.

My ex-wife and I met when we were just kids, barely 18, with the kind of naive hope that thinks love can conquer anything. She was my best friend, my other half, my safe place in a world that sometimes felt too big and too cold. When we stood there exchanging vows, I truly believed we’d be together forever. And maybe we could have been—if it was just us. But it wasn’t.

Her family had expectations. They wanted a doctor, a respected man with a title and prestige, someone who fit into their perfect image of success. They never said it outright, but every look, every subtle comment chipped away at me. They didn’t see me for who I was—they only saw the gap between who I was and who they thought I should be. And my wife…she was caught in the middle, torn between their love and mine.

We tried to make it work. God, we tried everything. We moved to different cities, created distance from her family, hoping that it would give us space to build something that was just ours. For a while, it worked, and I thought maybe we’d found a way. But every holiday, every phone call brought those expectations crashing back down on us. It was like her family’s hopes for her future were this invisible weight pressing down on us, one I couldn’t shake no matter how hard I tried.

My wife started to change. She didn’t want to, I could see that. But that constant tension wore on her. She looked at me like she was caught in a trap, like she was torn in two. And I felt powerless. I couldn’t ask her to choose, but I could see the pain she felt, the guilt she carried. Her family had her in their grip, and I was just another weight, pulling her in the opposite direction.

Eventually, we both broke. I remember the day we decided to separate. There wasn’t yelling or accusations, no one stormed out. It was quiet, like a mutual surrender. We sat on the couch, both of us just holding each other, crying, knowing that love wasn’t enough to save us from the world around us. And in that moment, I felt like my heart was being torn out of my chest.

I let go of the one person who knew me inside and out, not because I wanted to, but because I felt like I was suffocating. I thought that maybe, if I wasn’t in her life, she’d finally be free to live without that constant push and pull, free from the guilt and the expectations that haunted us. I thought I was doing something selfless, but the truth? I was broken. Walking away shattered me in ways I didn’t know were possible.

In the months after, I barely recognized myself. I was hollow, a shell of who I’d been, wondering if I’d made the biggest mistake of my life. Every day felt like a battle to just get out of bed, to go on with a life that suddenly felt like it wasn’t mine. And the worst part? The memories. Everywhere I looked, I saw her—our inside jokes, her smile, the way she’d curl up next to me at night. I felt haunted by a love that was still so painfully alive, yet completely out of reach.

I’ve spent the last two years trying to rebuild, piece by piece, but there’s a part of me that’s still living in that moment on the couch, holding her, crying, both of us knowing that what we had wasn’t strong enough to withstand the world. I still love her. I don’t think that will ever change. And I don’t know if I’ll ever truly move on.

People say time heals, but some wounds feel too deep to ever really close. I wanted to share this here, not because I’m looking for advice or sympathy, but because the weight of this loss is too much to carry alone. I lost myself trying to make a life with her, and now, in letting go, I’m still trying to find the pieces of who I am without her.

If you’re reading this, thank you. Sometimes, just putting it into words feels like the only way to make sense of it all."""

# %%
import spacy


nlp = spacy.load('en_core_web_sm')

# %%
doc = nlp(reddit_sample)

# %%
sentences = list(doc.sents)

# %%
for sentence in sentences:
    print(sentence.text)
# Out:
# Two years ago, I made the hardest, most soul-shattering decision of my life: I left my wife.
# Not because I stopped loving her or because we grew apart.
# I walked away because I couldn’t keep tearing myself apart, trying to be someone I wasn’t, to fit into a life that felt like it was slowly strangling me.
#
#
# My ex-wife and I met when we were just kids, barely 18, with the kind of naive hope that thinks love can conquer anything.
# She was my best friend, my other half, my safe place in a world that sometimes felt too big and too cold.
# When we stood there exchanging vows, I truly believed we’d be together forever.
# And maybe we could have been—if it was just us.
# But it wasn’t.
#
#
# Her family had expectations.
# They wanted a doctor, a respected man with a title and prestige, someone who fit into their perfect image of success.
# They never said it outright, but every look, every subtle comment chipped away at me.
# They didn’t see me for who I was—they only saw the gap between who I was and who they thought I should be.
# And my wife…she was caught in the middle, torn between their love and mine.
#
#
# We tried to make it work.
# God, we tried everything.
# We moved to different cities, created distance from her family, hoping that it would give us space to build something that was just ours.
# For a while, it worked, and I thought maybe we’d found a way.
# But every holiday, every phone call brought those expectations crashing back down on us.
# It was like her family’s hopes for her future were this invisible weight pressing down on us, one I couldn’t shake no matter how hard I tried.
#
#
# My wife started to change.
# She didn’t want to, I could see that.
# But that constant tension wore on her.
# She looked at me like she was caught in a trap, like she was torn in two.
# And I felt powerless.
# I couldn’t ask her to choose, but I could see the pain she felt, the guilt she carried.
# Her family had her in their grip, and I was just another weight, pulling her in the opposite direction.
#
#
# Eventually, we both broke.
# I remember the day we decided to separate.
# There wasn’t yelling or accusations, no one stormed out.
# It was quiet, like a mutual surrender.
# We sat on the couch, both of us just holding each other, crying, knowing that love wasn’t enough to save us from the world around us.
# And in that moment, I felt like my heart was being torn out of my chest.
#
#
# I let go of the one person who knew me inside and out, not because I wanted to, but because I felt like I was suffocating.
# I thought that maybe, if I wasn’t in her life, she’d finally be free to live without that constant push and pull, free from the guilt and the expectations that haunted us.
# I thought I was doing something selfless, but the truth?
# I was broken.
# Walking away shattered me in ways I didn’t know were possible.
#
#
# In the months after, I barely recognized myself.
# I was hollow, a shell of who I’d been, wondering if I’d made the biggest mistake of my life.
# Every day felt like a battle to just get out of bed, to go on with a life that suddenly felt like it wasn’t mine.
# And the worst part?
# The memories.
# Everywhere I looked, I saw her—our inside jokes, her smile, the way she’d curl up next to me at night.
# I felt haunted by a love that was still so painfully alive, yet completely out of reach.
#
#
# I’ve spent the last two years trying to rebuild, piece by piece, but there’s a part of me that’s still living in that moment on the couch, holding her, crying, both of us knowing that what we had wasn’t strong enough to withstand the world.
# I still love her.
# I don’t think that will ever change.
# And I don’t know if I’ll ever truly move on.
#
#
# People say time heals, but some wounds feel too deep to ever really close.
# I wanted to share this here, not because I’m looking for advice or sympathy, but because the weight of this loss is too much to carry alone.
# I lost myself trying to make a life with her, and now, in letting go, I’m still trying to find the pieces of who I am without her.
#
#
# If you’re reading this, thank you.
# Sometimes, just putting it into words feels like the only way to make sense of it all.

# %%
len(sentences)
# Out:
# 53

# %%
# prompt: Iterate through all sentences. If the sentence is just whitespace, skip over it. Otherwise, print it
sample = sentences[0:3]

for sam in sample:
  print(f"\"{sam.text}\" {sam.start_char}")
# Out:
# "Two years ago, I made the hardest, most soul-shattering decision of my life: I left my wife." 0
# "Not because I stopped loving her or because we grew apart." 93
# "I walked away because I couldn’t keep tearing myself apart, trying to be someone I wasn’t, to fit into a life that felt like it was slowly strangling me.
#
# " 152

# %%
bare_text = [sen.text.strip() for sen in sentences]

# %%
import torch

# Check for GPU
torch.backends.mps.is_available()
device = "mps" if torch.backends.mps.is_available() else "cpu"
print(f"Using device: {device}")
# Out:
# Using device: mps

# %%
from transformers import DistilBertTokenizer, DistilBertModel

# Load the DistilBERT model and tokenizer
tokenizer = DistilBertTokenizer.from_pretrained("distilbert-base-uncased")
model = DistilBertModel.from_pretrained("distilbert-base-uncased").to(device)

# %%
def embed_sentences(sentences):
    embeddings = []
    for sentence in sentences:
        # Tokenize and send to device
        inputs = tokenizer(sentence, return_tensors="pt", truncation=True, max_length=512).to(device)

        # Forward pass without gradients to save memory
        with torch.no_grad():
            outputs = model(**inputs)

        # Mean pooling on the last hidden state to get a single embedding vector for the sentence
        sentence_embedding = outputs.last_hidden_state.mean(dim=1).squeeze().cpu().numpy()
        embeddings.append(sentence_embedding)

    return embeddings

# %%
embeddings = embed_sentences(bare_text)
len(embeddings)
# Out:
# 53

# %%
from sklearn.cluster import KMeans
import numpy as np

# Define the number of initial clusters (e.g., 20 or 30 for 53 sentences)
n_initial_clusters = len(sentences)
kmeans = KMeans(n_clusters=n_initial_clusters, random_state=0)
labels = kmeans.fit_predict(np.array(embeddings))

# %%
from collections import defaultdict

# Group sentences by initial cluster labels
initial_chunks = defaultdict(list)
for sentence, label in zip(bare_text, labels):
    initial_chunks[label].append(sentence)

# Convert to a list of lists for further processing
initial_chunks_list = list(initial_chunks.values())

# %%
from sklearn.metrics.pairwise import cosine_similarity

# Define similarity threshold for merging clusters
similarity_threshold = 0.75
final_chunks = []
current_chunk = initial_chunks_list[0]

for i in range(1, len(initial_chunks_list)):
    # Calculate similarity between the last sentence of the current chunk and the first sentence of the next cluster
    similarity = cosine_similarity(
        [embed_sentences([current_chunk[-1]])[0]],
        [embed_sentences([initial_chunks_list[i][0]])[0]]
    )[0, 0]

    if similarity > similarity_threshold:
        current_chunk.extend(initial_chunks_list[i])
    else:
        final_chunks.append(current_chunk)
        current_chunk = initial_chunks_list[i]

# Append the last chunk
final_chunks.append(current_chunk)

# Display the results
for i, chunk in enumerate(final_chunks):
    print(f"Chunk {i + 1}: {chunk}\n")
# Out:
# Chunk 1: ['Two years ago, I made the hardest, most soul-shattering decision of my life: I left my wife.', 'Not because I stopped loving her or because we grew apart.', 'I walked away because I couldn’t keep tearing myself apart, trying to be someone I wasn’t, to fit into a life that felt like it was slowly strangling me.', 'My ex-wife and I met when we were just kids, barely 18, with the kind of naive hope that thinks love can conquer anything.', 'She was my best friend, my other half, my safe place in a world that sometimes felt too big and too cold.', 'When we stood there exchanging vows, I truly believed we’d be together forever.']
#
# Chunk 2: ['And maybe we could have been—if it was just us.', 'But it wasn’t.']
#
# Chunk 3: ['Her family had expectations.']
#
# Chunk 4: ['They wanted a doctor, a respected man with a title and prestige, someone who fit into their perfect image of success.']
#
# Chunk 5: ['They never said it outright, but every look, every subtle comment chipped away at me.', 'They didn’t see me for who I was—they only saw the gap between who I was and who they thought I should be.', 'And my wife…she was caught in the middle, torn between their love and mine.']
#
# Chunk 6: ['We tried to make it work.', 'God, we tried everything.']
#
# Chunk 7: ['We moved to different cities, created distance from her family, hoping that it would give us space to build something that was just ours.', 'For a while, it worked, and I thought maybe we’d found a way.']
#
# Chunk 8: ['But every holiday, every phone call brought those expectations crashing back down on us.', 'It was like her family’s hopes for her future were this invisible weight pressing down on us, one I couldn’t shake no matter how hard I tried.']
#
# Chunk 9: ['My wife started to change.', 'She didn’t want to, I could see that.', 'But that constant tension wore on her.']
#
# Chunk 10: ['She looked at me like she was caught in a trap, like she was torn in two.']
#
# Chunk 11: ['And I felt powerless.']
#
# Chunk 12: ['I couldn’t ask her to choose, but I could see the pain she felt, the guilt she carried.', 'Her family had her in their grip, and I was just another weight, pulling her in the opposite direction.']
#
# Chunk 13: ['Eventually, we both broke.', 'I remember the day we decided to separate.']
#
# Chunk 14: ['There wasn’t yelling or accusations, no one stormed out.', 'It was quiet, like a mutual surrender.']
#
# Chunk 15: ['We sat on the couch, both of us just holding each other, crying, knowing that love wasn’t enough to save us from the world around us.', 'And in that moment, I felt like my heart was being torn out of my chest.', 'I let go of the one person who knew me inside and out, not because I wanted to, but because I felt like I was suffocating.', 'I thought that maybe, if I wasn’t in her life, she’d finally be free to live without that constant push and pull, free from the guilt and the expectations that haunted us.', 'I thought I was doing something selfless, but the truth?', 'I was broken.', 'Walking away shattered me in ways I didn’t know were possible.', 'In the months after, I barely recognized myself.', 'I was hollow, a shell of who I’d been, wondering if I’d made the biggest mistake of my life.', 'Every day felt like a battle to just get out of bed, to go on with a life that suddenly felt like it wasn’t mine.']
#
# Chunk 16: ['And the worst part?', 'The memories.']
#
# Chunk 17: ['Everywhere I looked, I saw her—our inside jokes, her smile, the way she’d curl up next to me at night.', 'I felt haunted by a love that was still so painfully alive, yet completely out of reach.', 'I’ve spent the last two years trying to rebuild, piece by piece, but there’s a part of me that’s still living in that moment on the couch, holding her, crying, both of us knowing that what we had wasn’t strong enough to withstand the world.']
#
# Chunk 18: ['I still love her.', 'I don’t think that will ever change.', 'And I don’t know if I’ll ever truly move on.']
#
# Chunk 19: ['People say time heals, but some wounds feel too deep to ever really close.', 'I wanted to share this here, not because I’m looking for advice or sympathy, but because the weight of this loss is too much to carry alone.', 'I lost myself trying to make a life with her, and now, in letting go, I’m still trying to find the pieces of who I am without her.']
#
# Chunk 20: ['If you’re reading this, thank you.']
#
# Chunk 21: ['Sometimes, just putting it into words feels like the only way to make sense of it all.']

# %%
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

similarity_threshold = 0.75

# Initialize the list to store chunks, with each sentence as (index, text)
final_chunks = []
current_chunk = [(0, bare_text[0])]  # Start the first chunk with the first sentence and its index

# Iterate through sentences sequentially
for i in range(1, len(bare_text)):
    # Calculate similarity between the last sentence of the current chunk and the next sentence
    similarity = cosine_similarity(
        [embeddings[i - 1]], [embeddings[i]]
    )[0, 0]

    # If similarity is above the threshold, add to current chunk with the index
    if similarity >= similarity_threshold:
        current_chunk.append((i, bare_text[i]))  # Append as (index, text)
    else:
        # Otherwise, finalize the current chunk and start a new one
        final_chunks.append(current_chunk)
        current_chunk = [(i, bare_text[i])]  # Start a new chunk with the new sentence

# Append the last chunk if it wasn't added
if current_chunk:
    final_chunks.append(current_chunk)

# Display the results
for i, chunk in enumerate(final_chunks):
    print(f"Chunk {i + 1}:")
    for idx, sentence in chunk:
        print(f"Sentence {idx + 1}: {sentence}")
    print("\n")
# Out:
# Chunk 1:
# Sentence 1: Two years ago, I made the hardest, most soul-shattering decision of my life: I left my wife.
# Sentence 2: Not because I stopped loving her or because we grew apart.
# Sentence 3: I walked away because I couldn’t keep tearing myself apart, trying to be someone I wasn’t, to fit into a life that felt like it was slowly strangling me.
# Sentence 4: My ex-wife and I met when we were just kids, barely 18, with the kind of naive hope that thinks love can conquer anything.
# Sentence 5: She was my best friend, my other half, my safe place in a world that sometimes felt too big and too cold.
# Sentence 6: When we stood there exchanging vows, I truly believed we’d be together forever.
#
#
# Chunk 2:
# Sentence 7: And maybe we could have been—if it was just us.
# Sentence 8: But it wasn’t.
#
#
# Chunk 3:
# Sentence 9: Her family had expectations.
#
#
# Chunk 4:
# Sentence 10: They wanted a doctor, a respected man with a title and prestige, someone who fit into their perfect image of success.
#
#
# Chunk 5:
# Sentence 11: They never said it outright, but every look, every subtle comment chipped away at me.
# Sentence 12: They didn’t see me for who I was—they only saw the gap between who I was and who they thought I should be.
# Sentence 13: And my wife…she was caught in the middle, torn between their love and mine.
#
#
# Chunk 6:
# Sentence 14: We tried to make it work.
# Sentence 15: God, we tried everything.
#
#
# Chunk 7:
# Sentence 16: We moved to different cities, created distance from her family, hoping that it would give us space to build something that was just ours.
# Sentence 17: For a while, it worked, and I thought maybe we’d found a way.
#
#
# Chunk 8:
# Sentence 18: But every holiday, every phone call brought those expectations crashing back down on us.
# Sentence 19: It was like her family’s hopes for her future were this invisible weight pressing down on us, one I couldn’t shake no matter how hard I tried.
#
#
# Chunk 9:
# Sentence 20: My wife started to change.
# Sentence 21: She didn’t want to, I could see that.
# Sentence 22: But that constant tension wore on her.
#
#
# Chunk 10:
# Sentence 23: She looked at me like she was caught in a trap, like she was torn in two.
#
#
# Chunk 11:
# Sentence 24: And I felt powerless.
#
#
# Chunk 12:
# Sentence 25: I couldn’t ask her to choose, but I could see the pain she felt, the guilt she carried.
# Sentence 26: Her family had her in their grip, and I was just another weight, pulling her in the opposite direction.
#
#
# Chunk 13:
# Sentence 27: Eventually, we both broke.
# Sentence 28: I remember the day we decided to separate.
#
#
# Chunk 14:
# Sentence 29: There wasn’t yelling or accusations, no one stormed out.
# Sentence 30: It was quiet, like a mutual surrender.
#
#
# Chunk 15:
# Sentence 31: We sat on the couch, both of us just holding each other, crying, knowing that love wasn’t enough to save us from the world around us.
# Sentence 32: And in that moment, I felt like my heart was being torn out of my chest.
# Sentence 33: I let go of the one person who knew me inside and out, not because I wanted to, but because I felt like I was suffocating.
# Sentence 34: I thought that maybe, if I wasn’t in her life, she’d finally be free to live without that constant push and pull, free from the guilt and the expectations that haunted us.
# Sentence 35: I thought I was doing something selfless, but the truth?
# Sentence 36: I was broken.
# Sentence 37: Walking away shattered me in ways I didn’t know were possible.
# Sentence 38: In the months after, I barely recognized myself.
# Sentence 39: I was hollow, a shell of who I’d been, wondering if I’d made the biggest mistake of my life.
# Sentence 40: Every day felt like a battle to just get out of bed, to go on with a life that suddenly felt like it wasn’t mine.
#
#
# Chunk 16:
# Sentence 41: And the worst part?
# Sentence 42: The memories.
#
#
# Chunk 17:
# Sentence 43: Everywhere I looked, I saw her—our inside jokes, her smile, the way she’d curl up next to me at night.
# Sentence 44: I felt haunted by a love that was still so painfully alive, yet completely out of reach.
# Sentence 45: I’ve spent the last two years trying to rebuild, piece by piece, but there’s a part of me that’s still living in that moment on the couch, holding her, crying, both of us knowing that what we had wasn’t strong enough to withstand the world.
#
#
# Chunk 18:
# Sentence 46: I still love her.
# Sentence 47: I don’t think that will ever change.
# Sentence 48: And I don’t know if I’ll ever truly move on.
#
#
# Chunk 19:
# Sentence 49: People say time heals, but some wounds feel too deep to ever really close.
# Sentence 50: I wanted to share this here, not because I’m looking for advice or sympathy, but because the weight of this loss is too much to carry alone.
# Sentence 51: I lost myself trying to make a life with her, and now, in letting go, I’m still trying to find the pieces of who I am without her.
#
#
# Chunk 20:
# Sentence 52: If you’re reading this, thank you.
#
#
# Chunk 21:
# Sentence 53: Sometimes, just putting it into words feels like the only way to make sense of it all.

# %%
from transformers import pipeline

# Load the emotion detection pipeline
emotion_detector = pipeline("text-classification", model="j-hartmann/emotion-english-distilroberta-base", top_k=None, device=device)

# %%
def analyze_emotions_in_chunk(chunk_text):
    # Get emotion scores from the pipeline
    results = emotion_detector(chunk_text)

    # Process results to get a dictionary of emotions and their scores
    emotions = {item['label']: item['score'] for item in results[0]}

    # Return the chunk text and its emotions
    return {
        "chunk": chunk_text,
        "emotions": emotions
    }

# %%
# Analyze emotions for each chunk individually
chunk_emotions = []

for chunk in final_chunks:
    # Join only the sentence texts to create a single text passage for emotion detection
    chunk_text = " ".join(sentence for _, sentence in chunk)

    # Run emotion analysis on the joined text passage
    analysis_result = analyze_emotions_in_chunk(chunk_text)

    # Store only the 
    # irst and last indices of the sentences in this chunk
    start_index = chunk[0][0]
    end_index = chunk[-1][0]

    # Add the text, emotion analysis, and index range to the result
    analysis_result["start_index"] = start_index
    analysis_result["end_index"] = end_index
    chunk_emotions.append(analysis_result)

# Display results
for i, result in enumerate(chunk_emotions):
    print(f"Chunk {i + 1}:")
    print(f"Text: {result['chunk']}")
    print(f"Sentence Indices in Original Text: {result['start_index']} to {result['end_index']}")
    print("Emotions:")
    for emotion, score in result['emotions'].items():
        print(f"  {emotion}: {score:.3f}")
    print("\n")
# Out:
# Chunk 1:
# Text: Two years ago, I made the hardest, most soul-shattering decision of my life: I left my wife. Not because I stopped loving her or because we grew apart. I walked away because I couldn’t keep tearing myself apart, trying to be someone I wasn’t, to fit into a life that felt like it was slowly strangling me. My ex-wife and I met when we were just kids, barely 18, with the kind of naive hope that thinks love can conquer anything. She was my best friend, my other half, my safe place in a world that sometimes felt too big and too cold. When we stood there exchanging vows, I truly believed we’d be together forever.
# Sentence Indices in Original Text: 0 to 5
# Emotions:
#   sadness: 0.516
#   fear: 0.241
#   anger: 0.151
#   neutral: 0.045
#   disgust: 0.026
#   joy: 0.019
#   surprise: 0.002
#
#
# Chunk 2:
# Text: And maybe we could have been—if it was just us. But it wasn’t.
# Sentence Indices in Original Text: 6 to 7
# Emotions:
#   neutral: 0.779
#   surprise: 0.092
#   sadness: 0.045
#   disgust: 0.029
#   anger: 0.028
#   fear: 0.022
#   joy: 0.006
#
#
# Chunk 3:
# Text: Her family had expectations.
# Sentence Indices in Original Text: 8 to 8
# Emotions:
#   neutral: 0.796
#   disgust: 0.091
#   anger: 0.075
#   surprise: 0.018
#   sadness: 0.014
#   joy: 0.004
#   fear: 0.002
#
#
# Chunk 4:
# Text: They wanted a doctor, a respected man with a title and prestige, someone who fit into their perfect image of success.
# Sentence Indices in Original Text: 9 to 9
# Emotions:
#   neutral: 0.935
#   disgust: 0.017
#   joy: 0.017
#   surprise: 0.014
#   anger: 0.009
#   sadness: 0.006
#   fear: 0.001
#
#
# Chunk 5:
# Text: They never said it outright, but every look, every subtle comment chipped away at me. They didn’t see me for who I was—they only saw the gap between who I was and who they thought I should be. And my wife…she was caught in the middle, torn between their love and mine.
# Sentence Indices in Original Text: 10 to 12
# Emotions:
#   disgust: 0.335
#   neutral: 0.283
#   anger: 0.121
#   surprise: 0.115
#   fear: 0.093
#   sadness: 0.048
#   joy: 0.004
#
#
# Chunk 6:
# Text: We tried to make it work. God, we tried everything.
# Sentence Indices in Original Text: 13 to 14
# Emotions:
#   anger: 0.415
#   disgust: 0.296
#   surprise: 0.155
#   neutral: 0.076
#   sadness: 0.030
#   fear: 0.019
#   joy: 0.008
#
#
# Chunk 7:
# Text: We moved to different cities, created distance from her family, hoping that it would give us space to build something that was just ours. For a while, it worked, and I thought maybe we’d found a way.
# Sentence Indices in Original Text: 15 to 16
# Emotions:
#   neutral: 0.922
#   joy: 0.030
#   surprise: 0.016
#   disgust: 0.012
#   anger: 0.010
#   sadness: 0.007
#   fear: 0.003
#
#
# Chunk 8:
# Text: But every holiday, every phone call brought those expectations crashing back down on us. It was like her family’s hopes for her future were this invisible weight pressing down on us, one I couldn’t shake no matter how hard I tried.
# Sentence Indices in Original Text: 17 to 18
# Emotions:
#   fear: 0.918
#   surprise: 0.057
#   neutral: 0.011
#   anger: 0.005
#   disgust: 0.003
#   sadness: 0.003
#   joy: 0.002
#
#
# Chunk 9:
# Text: My wife started to change. She didn’t want to, I could see that. But that constant tension wore on her.
# Sentence Indices in Original Text: 19 to 21
# Emotions:
#   disgust: 0.520
#   anger: 0.179
#   neutral: 0.133
#   fear: 0.112
#   sadness: 0.044
#   surprise: 0.008
#   joy: 0.004
#
#
# Chunk 10:
# Text: She looked at me like she was caught in a trap, like she was torn in two.
# Sentence Indices in Original Text: 22 to 22
# Emotions:
#   disgust: 0.621
#   neutral: 0.210
#   fear: 0.068
#   anger: 0.045
#   surprise: 0.039
#   sadness: 0.015
#   joy: 0.001
#
#
# Chunk 11:
# Text: And I felt powerless.
# Sentence Indices in Original Text: 23 to 23
# Emotions:
#   fear: 0.693
#   sadness: 0.233
#   disgust: 0.032
#   neutral: 0.027
#   anger: 0.006
#   joy: 0.006
#   surprise: 0.003
#
#
# Chunk 12:
# Text: I couldn’t ask her to choose, but I could see the pain she felt, the guilt she carried. Her family had her in their grip, and I was just another weight, pulling her in the opposite direction.
# Sentence Indices in Original Text: 24 to 25
# Emotions:
#   sadness: 0.467
#   disgust: 0.244
#   neutral: 0.227
#   anger: 0.041
#   fear: 0.014
#   surprise: 0.004
#   joy: 0.003
#
#
# Chunk 13:
# Text: Eventually, we both broke. I remember the day we decided to separate.
# Sentence Indices in Original Text: 26 to 27
# Emotions:
#   sadness: 0.896
#   neutral: 0.041
#   disgust: 0.032
#   anger: 0.014
#   fear: 0.011
#   joy: 0.005
#   surprise: 0.002
#
#
# Chunk 14:
# Text: There wasn’t yelling or accusations, no one stormed out. It was quiet, like a mutual surrender.
# Sentence Indices in Original Text: 28 to 29
# Emotions:
#   neutral: 0.788
#   anger: 0.109
#   disgust: 0.060
#   fear: 0.022
#   sadness: 0.012
#   joy: 0.005
#   surprise: 0.004
#
#
# Chunk 15:
# Text: We sat on the couch, both of us just holding each other, crying, knowing that love wasn’t enough to save us from the world around us. And in that moment, I felt like my heart was being torn out of my chest. I let go of the one person who knew me inside and out, not because I wanted to, but because I felt like I was suffocating. I thought that maybe, if I wasn’t in her life, she’d finally be free to live without that constant push and pull, free from the guilt and the expectations that haunted us. I thought I was doing something selfless, but the truth? I was broken. Walking away shattered me in ways I didn’t know were possible. In the months after, I barely recognized myself. I was hollow, a shell of who I’d been, wondering if I’d made the biggest mistake of my life. Every day felt like a battle to just get out of bed, to go on with a life that suddenly felt like it wasn’t mine.
# Sentence Indices in Original Text: 30 to 39
# Emotions:
#   fear: 0.673
#   sadness: 0.272
#   neutral: 0.019
#   surprise: 0.016
#   disgust: 0.013
#   anger: 0.005
#   joy: 0.001
#
#
# Chunk 16:
# Text: And the worst part? The memories.
# Sentence Indices in Original Text: 40 to 41
# Emotions:
#   disgust: 0.987
#   anger: 0.006
#   neutral: 0.002
#   sadness: 0.002
#   fear: 0.002
#   surprise: 0.000
#   joy: 0.000
#
#
# Chunk 17:
# Text: Everywhere I looked, I saw her—our inside jokes, her smile, the way she’d curl up next to me at night. I felt haunted by a love that was still so painfully alive, yet completely out of reach. I’ve spent the last two years trying to rebuild, piece by piece, but there’s a part of me that’s still living in that moment on the couch, holding her, crying, both of us knowing that what we had wasn’t strong enough to withstand the world.
# Sentence Indices in Original Text: 42 to 44
# Emotions:
#   fear: 0.963
#   sadness: 0.012
#   neutral: 0.011
#   surprise: 0.007
#   disgust: 0.006
#   anger: 0.001
#   joy: 0.001
#
#
# Chunk 18:
# Text: I still love her. I don’t think that will ever change. And I don’t know if I’ll ever truly move on.
# Sentence Indices in Original Text: 45 to 47
# Emotions:
#   neutral: 0.702
#   sadness: 0.130
#   joy: 0.060
#   disgust: 0.036
#   fear: 0.033
#   surprise: 0.029
#   anger: 0.009
#
#
# Chunk 19:
# Text: People say time heals, but some wounds feel too deep to ever really close. I wanted to share this here, not because I’m looking for advice or sympathy, but because the weight of this loss is too much to carry alone. I lost myself trying to make a life with her, and now, in letting go, I’m still trying to find the pieces of who I am without her.
# Sentence Indices in Original Text: 48 to 50
# Emotions:
#   sadness: 0.944
#   neutral: 0.031
#   disgust: 0.011
#   fear: 0.007
#   surprise: 0.003
#   anger: 0.002
#   joy: 0.002
#
#
# Chunk 20:
# Text: If you’re reading this, thank you.
# Sentence Indices in Original Text: 51 to 51
# Emotions:
#   neutral: 0.543
#   joy: 0.356
#   surprise: 0.043
#   anger: 0.034
#   disgust: 0.018
#   sadness: 0.004
#   fear: 0.002
#
#
# Chunk 21:
# Text: Sometimes, just putting it into words feels like the only way to make sense of it all.
# Sentence Indices in Original Text: 52 to 52
# Emotions:
#   neutral: 0.910
#   disgust: 0.046
#   joy: 0.014
#   surprise: 0.013
#   anger: 0.011
#   sadness: 0.004
#   fear: 0.002

# %%
chunk_emotions
# Out:
# [{'chunk': 'Two years ago, I made the hardest, most soul-shattering decision of my life: I left my wife. Not because I stopped loving her or because we grew apart. I walked away because I couldn’t keep tearing myself apart, trying to be someone I wasn’t, to fit into a life that felt like it was slowly strangling me. My ex-wife and I met when we were just kids, barely 18, with the kind of naive hope that thinks love can conquer anything. She was my best friend, my other half, my safe place in a world that sometimes felt too big and too cold. When we stood there exchanging vows, I truly believed we’d be together forever.',
#   'emotions': {'sadness': 0.5159070491790771,
#    'fear': 0.24112895131111145,
#    'anger': 0.15117953717708588,
#    'neutral': 0.044702500104904175,
#    'disgust': 0.02556188590824604,
#    'joy': 0.019462812691926956,
#    'surprise': 0.002057280857115984},
#   'start_index': 0,
#   'end_index': 5},
#  {'chunk': 'And maybe we could have been—if it was just us. But it wasn’t.',
#   'emotions': {'neutral': 0.7788659930229187,
#    'surprise': 0.09171438962221146,
#    'sadness': 0.04542648792266846,
#    'disgust': 0.02862660400569439,
#    'anger': 0.027515392750501633,
#    'fear': 0.021906806156039238,
#    'joy': 0.00594433955848217},
#   'start_index': 6,
#   'end_index': 7},
#  {'chunk': 'Her family had expectations.',
#   'emotions': {'neutral': 0.7964175343513489,
#    'disgust': 0.09094103425741196,
#    'anger': 0.07476465404033661,
#    'surprise': 0.01752467453479767,
#    'sadness': 0.01374999899417162,
#    'joy': 0.004147005267441273,
#    'fear': 0.0024550389498472214},
#   'start_index': 8,
#   'end_index': 8},
#  {'chunk': 'They wanted a doctor, a respected man with a title and prestige, someone who fit into their perfect image of success.',
#   'emotions': {'neutral': 0.9353100657463074,
#    'disgust': 0.01706557720899582,
#    'joy': 0.017038200050592422,
#    'surprise': 0.014442616142332554,
#    'anger': 0.009322822093963623,
#    'sadness': 0.0057214610278606415,
#    'fear': 0.0010991638991981745},
#   'start_index': 9,
#   'end_index': 9},
#  {'chunk': 'They never said it outright, but every look, every subtle comment chipped away at me. They didn’t see me for who I was—they only saw the gap between who I was and who they thought I should be. And my wife…she was caught in the middle, torn between their love and mine.',
#   'emotions': {'disgust': 0.33540230989456177,
#    'neutral': 0.28342771530151367,
#    'anger': 0.12081120163202286,
#    'surprise': 0.11479801684617996,
#    'fear': 0.09347711503505707,
#    'sadness': 0.04817091301083565,
#    'joy': 0.003912714309990406},
#   'start_index': 10,
#   'end_index': 12},
#  {'chunk': 'We tried to make it work. God, we tried everything.',
#   'emotions': {'anger': 0.4145701825618744,
#    'disgust': 0.29618534445762634,
#    'surprise': 0.15545454621315002,
#    'neutral': 0.07638642191886902,
#    'sadness': 0.030125882476568222,
#    'fear': 0.01934133656322956,
#    'joy': 0.00793625321239233},
#   'start_index': 13,
#   'end_index': 14},
#  {'chunk': 'We moved to different cities, created distance from her family, hoping that it would give us space to build something that was just ours. For a while, it worked, and I thought maybe we’d found a way.',
#   'emotions': {'neutral': 0.922128438949585,
#    'joy': 0.030340755358338356,
#    'surprise': 0.015683501958847046,
#    'disgust': 0.011588400229811668,
#    'anger': 0.010461532510817051,
#    'sadness': 0.006897276733070612,
#    'fear': 0.0028999927453696728},
#   'start_index': 15,
#   'end_index': 16},
#  {'chunk': 'But every holiday, every phone call brought those expectations crashing back down on us. It was like her family’s hopes for her future were this invisible weight pressing down on us, one I couldn’t shake no matter how hard I tried.',
#   'emotions': {'fear': 0.918432891368866,
#    'surprise': 0.05653290078043938,
#    'neutral': 0.010990902781486511,
#    'anger': 0.005428514443337917,
#    'disgust': 0.003408093936741352,
#    'sadness': 0.002836678409948945,
#    'joy': 0.0023700660094618797},
#   'start_index': 17,
#   'end_index': 18},
#  {'chunk': 'My wife started to change. She didn’t want to, I could see that. But that constant tension wore on her.',
#   'emotions': {'disgust': 0.5203703045845032,
#    'anger': 0.1788242608308792,
#    'neutral': 0.13306540250778198,
#    'fear': 0.11246243864297867,
#    'sadness': 0.04350806772708893,
#    'surprise': 0.007685705553740263,
#    'joy': 0.004083848558366299},
#   'start_index': 19,
#   'end_index': 21},
#  {'chunk': 'She looked at me like she was caught in a trap, like she was torn in two.',
#   'emotions': {'disgust': 0.6213756799697876,
#    'neutral': 0.21038387715816498,
#    'fear': 0.06842099875211716,
#    'anger': 0.04453124478459358,
#    'surprise': 0.038742851465940475,
#    'sadness': 0.01524400059133768,
#    'joy': 0.0013012996641919017},
#   'start_index': 22,
#   'end_index': 22},
#  {'chunk': 'And I felt powerless.',
#   'emotions': {'fear': 0.6928600072860718,
#    'sadness': 0.2329462766647339,
#    'disgust': 0.0320667140185833,
#    'neutral': 0.026874655857682228,
#    'anger': 0.006197071634232998,
#    'joy': 0.006062457337975502,
#    'surprise': 0.0029928726144135},
#   'start_index': 23,
#   'end_index': 23},
#  {'chunk': 'I couldn’t ask her to choose, but I could see the pain she felt, the guilt she carried. Her family had her in their grip, and I was just another weight, pulling her in the opposite direction.',
#   'emotions': {'sadness': 0.46668463945388794,
#    'disgust': 0.24354393780231476,
#    'neutral': 0.22718995809555054,
#    'anger': 0.04101772606372833,
#    'fear': 0.014421312138438225,
#    'surprise': 0.0039861309342086315,
#    'joy': 0.0031563295051455498},
#   'start_index': 24,
#   'end_index': 25},
#  {'chunk': 'Eventually, we both broke. I remember the day we decided to separate.',
#   'emotions': {'sadness': 0.8960074186325073,
#    'neutral': 0.04051489010453224,
#    'disgust': 0.03197414427995682,
#    'anger': 0.013523870147764683,
#    'fear': 0.010632884688675404,
#    'joy': 0.004976626951247454,
#    'surprise': 0.002370193600654602},
#   'start_index': 26,
#   'end_index': 27},
#  {'chunk': 'There wasn’t yelling or accusations, no one stormed out. It was quiet, like a mutual surrender.',
#   'emotions': {'neutral': 0.7878425121307373,
#    'anger': 0.1091037169098854,
#    'disgust': 0.06008471921086311,
#    'fear': 0.021982459351420403,
#    'sadness': 0.012007933109998703,
#    'joy': 0.005031501408666372,
#    'surprise': 0.003947186283767223},
#   'start_index': 28,
#   'end_index': 29},
#  {'chunk': 'We sat on the couch, both of us just holding each other, crying, knowing that love wasn’t enough to save us from the world around us. And in that moment, I felt like my heart was being torn out of my chest. I let go of the one person who knew me inside and out, not because I wanted to, but because I felt like I was suffocating. I thought that maybe, if I wasn’t in her life, she’d finally be free to live without that constant push and pull, free from the guilt and the expectations that haunted us. I thought I was doing something selfless, but the truth? I was broken. Walking away shattered me in ways I didn’t know were possible. In the months after, I barely recognized myself. I was hollow, a shell of who I’d been, wondering if I’d made the biggest mistake of my life. Every day felt like a battle to just get out of bed, to go on with a life that suddenly felt like it wasn’t mine.',
#   'emotions': {'fear': 0.6733579635620117,
#    'sadness': 0.2716788351535797,
#    'neutral': 0.01886005699634552,
#    'surprise': 0.015726331621408463,
#    'disgust': 0.01349596120417118,
#    'anger': 0.00539202056825161,
#    'joy': 0.0014888712903484702},
#   'start_index': 30,
#   'end_index': 39},
#  {'chunk': 'And the worst part? The memories.',
#   'emotions': {'disgust': 0.9872612953186035,
#    'anger': 0.00568661093711853,
#    'neutral': 0.0023104327265173197,
#    'sadness': 0.002129108877852559,
#    'fear': 0.0018312514293938875,
#    'surprise': 0.0004300081345718354,
#    'joy': 0.0003513444971758872},
#   'start_index': 40,
#   'end_index': 41},
#  {'chunk': 'Everywhere I looked, I saw her—our inside jokes, her smile, the way she’d curl up next to me at night. I felt haunted by a love that was still so painfully alive, yet completely out of reach. I’ve spent the last two years trying to rebuild, piece by piece, but there’s a part of me that’s still living in that moment on the couch, holding her, crying, both of us knowing that what we had wasn’t strong enough to withstand the world.',
#   'emotions': {'fear': 0.9625272750854492,
#    'sadness': 0.011871560476720333,
#    'neutral': 0.011041444726288319,
#    'surprise': 0.006868314929306507,
#    'disgust': 0.005817159079015255,
#    'anger': 0.0011431955499574542,
#    'joy': 0.0007310013752430677},
#   'start_index': 42,
#   'end_index': 44},
#  {'chunk': 'I still love her. I don’t think that will ever change. And I don’t know if I’ll ever truly move on.',
#   'emotions': {'neutral': 0.7018822431564331,
#    'sadness': 0.13044902682304382,
#    'joy': 0.06004420295357704,
#    'disgust': 0.03639974817633629,
#    'fear': 0.03279303386807442,
#    'surprise': 0.029451044276356697,
#    'anger': 0.00898072961717844},
#   'start_index': 45,
#   'end_index': 47},
#  {'chunk': 'People say time heals, but some wounds feel too deep to ever really close. I wanted to share this here, not because I’m looking for advice or sympathy, but because the weight of this loss is too much to carry alone. I lost myself trying to make a life with her, and now, in letting go, I’m still trying to find the pieces of who I am without her.',
#   'emotions': {'sadness': 0.9443084001541138,
#    'neutral': 0.0313507616519928,
#    'disgust': 0.01071072742342949,
#    'fear': 0.0068193781189620495,
#    'surprise': 0.002821772824972868,
#    'anger': 0.002422923455014825,
#    'joy': 0.0015660482458770275},
#   'start_index': 48,
#   'end_index': 50},
#  {'chunk': 'If you’re reading this, thank you.',
#   'emotions': {'neutral': 0.5433118343353271,
#    'joy': 0.35562193393707275,
#    'surprise': 0.04331498593091965,
#    'anger': 0.03412221744656563,
#    'disgust': 0.018331188708543777,
#    'sadness': 0.0035707049537450075,
#    'fear': 0.0017271428368985653},
#   'start_index': 51,
#   'end_index': 51},
#  {'chunk': 'Sometimes, just putting it into words feels like the only way to make sense of it all.',
#   'emotions': {'neutral': 0.9103854894638062,
#    'disgust': 0.046296171844005585,
#    'joy': 0.014186663553118706,
#    'surprise': 0.012762464582920074,
#    'anger': 0.010651607997715473,
#    'sadness': 0.003637748071923852,
#    'fear': 0.002079857513308525},
#   'start_index': 52,
#   'end_index': 52}]

# %%
for chunk in chunk_emotions:
  first_sentence = sentences[chunk['start_index']]
  last_sentence = sentences[chunk['end_index']]
  print(f"{first_sentence.start_char} - {last_sentence.end_char}")
  print(" Emotions:")
  for emotion, score in chunk['emotions'].items():
    print(f"  {emotion}: {score:.3f}")
  print()
# Out:
# 0 - 615
#  Emotions:
#   sadness: 0.516
#   fear: 0.241
#   anger: 0.151
#   neutral: 0.045
#   disgust: 0.026
#   joy: 0.019
#   surprise: 0.002
#
# 616 - 680
#  Emotions:
#   neutral: 0.779
#   surprise: 0.092
#   sadness: 0.045
#   disgust: 0.029
#   anger: 0.028
#   fear: 0.022
#   joy: 0.006
#
# 680 - 708
#  Emotions:
#   neutral: 0.796
#   disgust: 0.091
#   anger: 0.075
#   surprise: 0.018
#   sadness: 0.014
#   joy: 0.004
#   fear: 0.002
#
# 709 - 826
#  Emotions:
#   neutral: 0.935
#   disgust: 0.017
#   joy: 0.017
#   surprise: 0.014
#   anger: 0.009
#   sadness: 0.006
#   fear: 0.001
#
# 827 - 1097
#  Emotions:
#   disgust: 0.335
#   neutral: 0.283
#   anger: 0.121
#   surprise: 0.115
#   fear: 0.093
#   sadness: 0.048
#   joy: 0.004
#
# 1097 - 1148
#  Emotions:
#   anger: 0.415
#   disgust: 0.296
#   surprise: 0.155
#   neutral: 0.076
#   sadness: 0.030
#   fear: 0.019
#   joy: 0.008
#
# 1149 - 1348
#  Emotions:
#   neutral: 0.922
#   joy: 0.030
#   surprise: 0.016
#   disgust: 0.012
#   anger: 0.010
#   sadness: 0.007
#   fear: 0.003
#
# 1349 - 1582
#  Emotions:
#   fear: 0.918
#   surprise: 0.057
#   neutral: 0.011
#   anger: 0.005
#   disgust: 0.003
#   sadness: 0.003
#   joy: 0.002
#
# 1582 - 1685
#  Emotions:
#   disgust: 0.520
#   anger: 0.179
#   neutral: 0.133
#   fear: 0.112
#   sadness: 0.044
#   surprise: 0.008
#   joy: 0.004
#
# 1686 - 1759
#  Emotions:
#   disgust: 0.621
#   neutral: 0.210
#   fear: 0.068
#   anger: 0.045
#   surprise: 0.039
#   sadness: 0.015
#   joy: 0.001
#
# 1760 - 1781
#  Emotions:
#   fear: 0.693
#   sadness: 0.233
#   disgust: 0.032
#   neutral: 0.027
#   anger: 0.006
#   joy: 0.006
#   surprise: 0.003
#
# 1782 - 1975
#  Emotions:
#   sadness: 0.467
#   disgust: 0.244
#   neutral: 0.227
#   anger: 0.041
#   fear: 0.014
#   surprise: 0.004
#   joy: 0.003
#
# 1975 - 2044
#  Emotions:
#   sadness: 0.896
#   neutral: 0.041
#   disgust: 0.032
#   anger: 0.014
#   fear: 0.011
#   joy: 0.005
#   surprise: 0.002
#
# 2045 - 2140
#  Emotions:
#   neutral: 0.788
#   anger: 0.109
#   disgust: 0.060
#   fear: 0.022
#   sadness: 0.012
#   joy: 0.005
#   surprise: 0.004
#
# 2141 - 3034
#  Emotions:
#   fear: 0.673
#   sadness: 0.272
#   neutral: 0.019
#   surprise: 0.016
#   disgust: 0.013
#   anger: 0.005
#   joy: 0.001
#
# 3035 - 3068
#  Emotions:
#   disgust: 0.987
#   anger: 0.006
#   neutral: 0.002
#   sadness: 0.002
#   fear: 0.002
#   surprise: 0.000
#   joy: 0.000
#
# 3069 - 3502
#  Emotions:
#   fear: 0.963
#   sadness: 0.012
#   neutral: 0.011
#   surprise: 0.007
#   disgust: 0.006
#   anger: 0.001
#   joy: 0.001
#
# 3503 - 3604
#  Emotions:
#   neutral: 0.702
#   sadness: 0.130
#   joy: 0.060
#   disgust: 0.036
#   fear: 0.033
#   surprise: 0.029
#   anger: 0.009
#
# 3604 - 3952
#  Emotions:
#   sadness: 0.944
#   neutral: 0.031
#   disgust: 0.011
#   fear: 0.007
#   surprise: 0.003
#   anger: 0.002
#   joy: 0.002
#
# 3952 - 3986
#  Emotions:
#   neutral: 0.543
#   joy: 0.356
#   surprise: 0.043
#   anger: 0.034
#   disgust: 0.018
#   sadness: 0.004
#   fear: 0.002
#
# 3987 - 4073
#  Emotions:
#   neutral: 0.910
#   disgust: 0.046
#   joy: 0.014
#   surprise: 0.013
#   anger: 0.011
#   sadness: 0.004
#   fear: 0.002
