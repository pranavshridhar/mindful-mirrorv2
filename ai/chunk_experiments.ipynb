# %%
reddit_sample = """Two years ago, I made the hardest, most soul-shattering decision of my life: I left my wife. Not because I stopped loving her or because we grew apart. I walked away because I couldn’t keep tearing myself apart, trying to be someone I wasn’t, to fit into a life that felt like it was slowly strangling me.

My ex-wife and I met when we were just kids, barely 18, with the kind of naive hope that thinks love can conquer anything. She was my best friend, my other half, my safe place in a world that sometimes felt too big and too cold. When we stood there exchanging vows, I truly believed we’d be together forever. And maybe we could have been—if it was just us. But it wasn’t.

Her family had expectations. They wanted a doctor, a respected man with a title and prestige, someone who fit into their perfect image of success. They never said it outright, but every look, every subtle comment chipped away at me. They didn’t see me for who I was—they only saw the gap between who I was and who they thought I should be. And my wife…she was caught in the middle, torn between their love and mine.

We tried to make it work. God, we tried everything. We moved to different cities, created distance from her family, hoping that it would give us space to build something that was just ours. For a while, it worked, and I thought maybe we’d found a way. But every holiday, every phone call brought those expectations crashing back down on us. It was like her family’s hopes for her future were this invisible weight pressing down on us, one I couldn’t shake no matter how hard I tried.

My wife started to change. She didn’t want to, I could see that. But that constant tension wore on her. She looked at me like she was caught in a trap, like she was torn in two. And I felt powerless. I couldn’t ask her to choose, but I could see the pain she felt, the guilt she carried. Her family had her in their grip, and I was just another weight, pulling her in the opposite direction.

Eventually, we both broke. I remember the day we decided to separate. There wasn’t yelling or accusations, no one stormed out. It was quiet, like a mutual surrender. We sat on the couch, both of us just holding each other, crying, knowing that love wasn’t enough to save us from the world around us. And in that moment, I felt like my heart was being torn out of my chest.

I let go of the one person who knew me inside and out, not because I wanted to, but because I felt like I was suffocating. I thought that maybe, if I wasn’t in her life, she’d finally be free to live without that constant push and pull, free from the guilt and the expectations that haunted us. I thought I was doing something selfless, but the truth? I was broken. Walking away shattered me in ways I didn’t know were possible.

In the months after, I barely recognized myself. I was hollow, a shell of who I’d been, wondering if I’d made the biggest mistake of my life. Every day felt like a battle to just get out of bed, to go on with a life that suddenly felt like it wasn’t mine. And the worst part? The memories. Everywhere I looked, I saw her—our inside jokes, her smile, the way she’d curl up next to me at night. I felt haunted by a love that was still so painfully alive, yet completely out of reach.

I’ve spent the last two years trying to rebuild, piece by piece, but there’s a part of me that’s still living in that moment on the couch, holding her, crying, both of us knowing that what we had wasn’t strong enough to withstand the world. I still love her. I don’t think that will ever change. And I don’t know if I’ll ever truly move on.

People say time heals, but some wounds feel too deep to ever really close. I wanted to share this here, not because I’m looking for advice or sympathy, but because the weight of this loss is too much to carry alone. I lost myself trying to make a life with her, and now, in letting go, I’m still trying to find the pieces of who I am without her.

If you’re reading this, thank you. Sometimes, just putting it into words feels like the only way to make sense of it all."""
# Out:
# Running cells with 'Python 3.12.3' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
import spacy


nlp = spacy.load('en_core_web_sm')

# %%
doc = nlp(reddit_sample)

# %%
sentences = list(doc.sents)

# %%
for sentence in sentences:
    print(sentence.text)
# Out:
# Two years ago, I made the hardest, most soul-shattering decision of my life: I left my wife.
# Not because I stopped loving her or because we grew apart.
# I walked away because I couldn’t keep tearing myself apart, trying to be someone I wasn’t, to fit into a life that felt like it was slowly strangling me.
#
#
# My ex-wife
# and I met when we were just kids, barely 18, with the kind of naive hope that thinks love can conquer anything.
# She was my best friend, my other half, my safe place in a world that sometimes felt too big and too cold.
# When we stood there exchanging vows, I truly believed we’d be together forever.
# And maybe we could have been—if it was just us.
# But it wasn’t.
#
#
# Her family had expectations.
# They wanted a doctor, a respected man with a title and prestige, someone who fit into their perfect image of success.
# They never said it outright, but every look, every subtle comment chipped away at me.
# They didn’t see me for who I was—they only saw the gap between who I was and who they thought I should be.
# And my wife…she was caught in the middle, torn between their love and mine.
#
#
# We tried to make it work.
# God, we tried everything.
# We moved to different cities, created distance from her family, hoping that it would give us space to build something that was just ours.
# For a while, it worked, and I thought maybe we’d found a way.
# But every holiday, every phone call brought those expectations crashing back down on us.
# It was like her family’s hopes for her future were this invisible weight pressing down on us, one I couldn’t shake no matter how hard I tried.
#
#
# My wife started to change.
# She didn’t want to, I could see that.
# But that constant tension wore on her.
# She looked at me like she was caught in a trap, like she was torn in two.
# And I felt powerless.
# I couldn’t ask her to choose, but I could see the pain she felt, the guilt she carried.
# Her family had her in their grip, and I was just another weight, pulling her in the opposite direction.
#
#
# Eventually, we both broke.
# I remember the day we decided to separate.
# There wasn’t yelling or accusations, no one stormed out.
# It was quiet, like a mutual surrender.
# We sat on the couch, both of us just holding each other, crying, knowing that love wasn’t enough to save us from the world around us.
# And in that moment, I felt like my heart was being torn out of my chest.
#
#
# I let go of the one person who knew me inside and out, not because I wanted to, but because I felt like I was suffocating.
# I thought that maybe, if I wasn’t in her life, she’d finally be free to live without that constant push and pull, free from the guilt and the expectations that haunted us.
# I thought I was doing something selfless, but the truth?
# I was broken.
# Walking away shattered me in ways I didn’t know were possible.
#
#
# In the months after, I barely recognized myself.
# I was hollow, a shell of who I’d been, wondering if I’d made the biggest mistake of my life.
# Every day felt like a battle to just get out of bed, to go on with a life that suddenly felt like it wasn’t mine.
# And the worst part?
# The memories.
# Everywhere I looked, I saw her—our inside jokes, her smile, the way she’d curl up next to me at night.
# I felt haunted by a love that was still so painfully alive, yet completely out of reach.
#
#
# I’ve spent the last two years trying to rebuild, piece by piece, but there’s a part of me that’s still living in that moment on the couch, holding her, crying, both of us knowing that what we had wasn’t strong enough to withstand the world.
# I still love her.
# I don’t think that will ever change.
# And I don’t know if I’ll ever truly move on.
#
#
# People say time heals, but some wounds feel too deep to ever really close.
# I wanted to share this here, not because I’m looking for advice or sympathy, but because the weight of this loss is too much to carry alone.
# I lost myself trying to make a life with her, and now, in letting go, I’m still trying to find the pieces of who I am without her.
#
#
# If you’re reading this, thank you.
# Sometimes, just putting it into words feels like the only way to make sense of it all.

# %%
len(sentences)
# Out:
# 54

# %%
# prompt: Iterate through all sentences. If the sentence is just whitespace, skip over it. Otherwise, print it
sample = sentences[0:3]

for sam in sample:
  print(f"\"{sam.text}\" {sam.start_char}")
# Out:
# "Two years ago, I made the hardest, most soul-shattering decision of my life: I left my wife." 0
# "Not because I stopped loving her or because we grew apart." 93
# "I walked away because I couldn’t keep tearing myself apart, trying to be someone I wasn’t, to fit into a life that felt like it was slowly strangling me.
#
# " 152

# %%
bare_text = [sen.text.strip() for sen in sentences]

# %%
import torch.backends
import torch.cuda
import torch

# Check for GPU
torch.backends.mps.is_available()
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
from transformers import DistilBertTokenizer, DistilBertModel

# Load the DistilBERT model and tokenizer
tokenizer = DistilBertTokenizer.from_pretrained("distilbert-base-uncased")
model = DistilBertModel.from_pretrained("distilbert-base-uncased").to(device)

# %%
def embed_sentences(sentences):
    embeddings = []
    for sentence in sentences:
        # Tokenize and send to device
        inputs = tokenizer(sentence, return_tensors="pt", truncation=True, max_length=512).to(device)

        # Forward pass without gradients to save memory
        with torch.no_grad():
            outputs = model(**inputs)

        # Mean pooling on the last hidden state to get a single embedding vector for the sentence
        sentence_embedding = outputs.last_hidden_state.mean(dim=1).squeeze().cpu().numpy()
        embeddings.append(sentence_embedding)

    return embeddings

# %%
embeddings = embed_sentences(bare_text)
len(embeddings)
# Out:
# 54

# %%
from sklearn.cluster import KMeans
import numpy as np

# Define the number of initial clusters (e.g., 20 or 30 for 53 sentences)
n_initial_clusters = len(sentences)
kmeans = KMeans(n_clusters=n_initial_clusters, random_state=0)
labels = kmeans.fit_predict(np.array(embeddings))

# %%
from collections import defaultdict

# Group sentences by initial cluster labels
initial_chunks = defaultdict(list)
for sentence, label in zip(bare_text, labels):
    initial_chunks[label].append(sentence)

# Convert to a list of lists for further processing
initial_chunks_list = list(initial_chunks.values())

# %%
from sklearn.metrics.pairwise import cosine_similarity

# Define similarity threshold for merging clusters
similarity_threshold = 0.75
final_chunks = []
current_chunk = initial_chunks_list[0]

for i in range(1, len(initial_chunks_list)):
    # Calculate similarity between the last sentence of the current chunk and the first sentence of the next cluster
    similarity = cosine_similarity(
        [embed_sentences([current_chunk[-1]])[0]],
        [embed_sentences([initial_chunks_list[i][0]])[0]]
    )[0, 0]

    if similarity > similarity_threshold:
        current_chunk.extend(initial_chunks_list[i])
    else:
        final_chunks.append(current_chunk)
        current_chunk = initial_chunks_list[i]

# Append the last chunk
final_chunks.append(current_chunk)

# Display the results
for i, chunk in enumerate(final_chunks):
    print(f"Chunk {i + 1}: {chunk}\n")
# Out:
# Chunk 1: ['Two years ago, I made the hardest, most soul-shattering decision of my life: I left my wife.', 'Not because I stopped loving her or because we grew apart.', 'I walked away because I couldn’t keep tearing myself apart, trying to be someone I wasn’t, to fit into a life that felt like it was slowly strangling me.']
#
# Chunk 2: ['My ex-wife']
#
# Chunk 3: ['and I met when we were just kids, barely 18, with the kind of naive hope that thinks love can conquer anything.', 'She was my best friend, my other half, my safe place in a world that sometimes felt too big and too cold.', 'When we stood there exchanging vows, I truly believed we’d be together forever.']
#
# Chunk 4: ['And maybe we could have been—if it was just us.', 'But it wasn’t.']
#
# Chunk 5: ['Her family had expectations.']
#
# Chunk 6: ['They wanted a doctor, a respected man with a title and prestige, someone who fit into their perfect image of success.']
#
# Chunk 7: ['They never said it outright, but every look, every subtle comment chipped away at me.', 'They didn’t see me for who I was—they only saw the gap between who I was and who they thought I should be.', 'And my wife…she was caught in the middle, torn between their love and mine.']
#
# Chunk 8: ['We tried to make it work.', 'God, we tried everything.']
#
# Chunk 9: ['We moved to different cities, created distance from her family, hoping that it would give us space to build something that was just ours.', 'For a while, it worked, and I thought maybe we’d found a way.']
#
# Chunk 10: ['But every holiday, every phone call brought those expectations crashing back down on us.', 'It was like her family’s hopes for her future were this invisible weight pressing down on us, one I couldn’t shake no matter how hard I tried.']
#
# Chunk 11: ['My wife started to change.', 'She didn’t want to, I could see that.', 'But that constant tension wore on her.']
#
# Chunk 12: ['She looked at me like she was caught in a trap, like she was torn in two.']
#
# Chunk 13: ['And I felt powerless.']
#
# Chunk 14: ['I couldn’t ask her to choose, but I could see the pain she felt, the guilt she carried.', 'Her family had her in their grip, and I was just another weight, pulling her in the opposite direction.']
#
# Chunk 15: ['Eventually, we both broke.', 'I remember the day we decided to separate.']
#
# Chunk 16: ['There wasn’t yelling or accusations, no one stormed out.', 'It was quiet, like a mutual surrender.']
#
# Chunk 17: ['We sat on the couch, both of us just holding each other, crying, knowing that love wasn’t enough to save us from the world around us.', 'And in that moment, I felt like my heart was being torn out of my chest.', 'I let go of the one person who knew me inside and out, not because I wanted to, but because I felt like I was suffocating.', 'I thought that maybe, if I wasn’t in her life, she’d finally be free to live without that constant push and pull, free from the guilt and the expectations that haunted us.', 'I thought I was doing something selfless, but the truth?', 'I was broken.', 'Walking away shattered me in ways I didn’t know were possible.', 'In the months after, I barely recognized myself.', 'I was hollow, a shell of who I’d been, wondering if I’d made the biggest mistake of my life.', 'Every day felt like a battle to just get out of bed, to go on with a life that suddenly felt like it wasn’t mine.']
#
# Chunk 18: ['And the worst part?', 'The memories.']
#
# Chunk 19: ['Everywhere I looked, I saw her—our inside jokes, her smile, the way she’d curl up next to me at night.', 'I felt haunted by a love that was still so painfully alive, yet completely out of reach.', 'I’ve spent the last two years trying to rebuild, piece by piece, but there’s a part of me that’s still living in that moment on the couch, holding her, crying, both of us knowing that what we had wasn’t strong enough to withstand the world.']
#
# Chunk 20: ['I still love her.', 'I don’t think that will ever change.', 'And I don’t know if I’ll ever truly move on.']
#
# Chunk 21: ['People say time heals, but some wounds feel too deep to ever really close.', 'I wanted to share this here, not because I’m looking for advice or sympathy, but because the weight of this loss is too much to carry alone.', 'I lost myself trying to make a life with her, and now, in letting go, I’m still trying to find the pieces of who I am without her.']
#
# Chunk 22: ['If you’re reading this, thank you.']
#
# Chunk 23: ['Sometimes, just putting it into words feels like the only way to make sense of it all.']

# %%
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

similarity_threshold = 0.75

# Initialize the list to store chunks, with each sentence as (index, text)
final_chunks = []
current_chunk = [(0, bare_text[0])]  # Start the first chunk with the first sentence and its index

# Iterate through sentences sequentially
for i in range(1, len(bare_text)):
    # Calculate similarity between the last sentence of the current chunk and the next sentence
    similarity = cosine_similarity(
        [embeddings[i - 1]], [embeddings[i]]
    )[0, 0]

    # If similarity is above the threshold, add to current chunk with the index
    if similarity >= similarity_threshold:
        current_chunk.append((i, bare_text[i]))  # Append as (index, text)
    else:
        # Otherwise, finalize the current chunk and start a new one
        final_chunks.append(current_chunk)
        current_chunk = [(i, bare_text[i])]  # Start a new chunk with the new sentence

# Append the last chunk if it wasn't added
if current_chunk:
    final_chunks.append(current_chunk)

# Display the results
for i, chunk in enumerate(final_chunks):
    print(f"Chunk {i + 1}:")
    for idx, sentence in chunk:
        print(f"Sentence {idx + 1}: {sentence}")
    print("\n")
# Out:
# Chunk 1:
# Sentence 1: Two years ago, I made the hardest, most soul-shattering decision of my life: I left my wife.
# Sentence 2: Not because I stopped loving her or because we grew apart.
# Sentence 3: I walked away because I couldn’t keep tearing myself apart, trying to be someone I wasn’t, to fit into a life that felt like it was slowly strangling me.
#
#
# Chunk 2:
# Sentence 4: My ex-wife
#
#
# Chunk 3:
# Sentence 5: and I met when we were just kids, barely 18, with the kind of naive hope that thinks love can conquer anything.
# Sentence 6: She was my best friend, my other half, my safe place in a world that sometimes felt too big and too cold.
# Sentence 7: When we stood there exchanging vows, I truly believed we’d be together forever.
#
#
# Chunk 4:
# Sentence 8: And maybe we could have been—if it was just us.
# Sentence 9: But it wasn’t.
#
#
# Chunk 5:
# Sentence 10: Her family had expectations.
#
#
# Chunk 6:
# Sentence 11: They wanted a doctor, a respected man with a title and prestige, someone who fit into their perfect image of success.
#
#
# Chunk 7:
# Sentence 12: They never said it outright, but every look, every subtle comment chipped away at me.
# Sentence 13: They didn’t see me for who I was—they only saw the gap between who I was and who they thought I should be.
# Sentence 14: And my wife…she was caught in the middle, torn between their love and mine.
#
#
# Chunk 8:
# Sentence 15: We tried to make it work.
# Sentence 16: God, we tried everything.
#
#
# Chunk 9:
# Sentence 17: We moved to different cities, created distance from her family, hoping that it would give us space to build something that was just ours.
# Sentence 18: For a while, it worked, and I thought maybe we’d found a way.
#
#
# Chunk 10:
# Sentence 19: But every holiday, every phone call brought those expectations crashing back down on us.
# Sentence 20: It was like her family’s hopes for her future were this invisible weight pressing down on us, one I couldn’t shake no matter how hard I tried.
#
#
# Chunk 11:
# Sentence 21: My wife started to change.
# Sentence 22: She didn’t want to, I could see that.
# Sentence 23: But that constant tension wore on her.
#
#
# Chunk 12:
# Sentence 24: She looked at me like she was caught in a trap, like she was torn in two.
#
#
# Chunk 13:
# Sentence 25: And I felt powerless.
#
#
# Chunk 14:
# Sentence 26: I couldn’t ask her to choose, but I could see the pain she felt, the guilt she carried.
# Sentence 27: Her family had her in their grip, and I was just another weight, pulling her in the opposite direction.
#
#
# Chunk 15:
# Sentence 28: Eventually, we both broke.
# Sentence 29: I remember the day we decided to separate.
#
#
# Chunk 16:
# Sentence 30: There wasn’t yelling or accusations, no one stormed out.
# Sentence 31: It was quiet, like a mutual surrender.
#
#
# Chunk 17:
# Sentence 32: We sat on the couch, both of us just holding each other, crying, knowing that love wasn’t enough to save us from the world around us.
# Sentence 33: And in that moment, I felt like my heart was being torn out of my chest.
# Sentence 34: I let go of the one person who knew me inside and out, not because I wanted to, but because I felt like I was suffocating.
# Sentence 35: I thought that maybe, if I wasn’t in her life, she’d finally be free to live without that constant push and pull, free from the guilt and the expectations that haunted us.
# Sentence 36: I thought I was doing something selfless, but the truth?
# Sentence 37: I was broken.
# Sentence 38: Walking away shattered me in ways I didn’t know were possible.
# Sentence 39: In the months after, I barely recognized myself.
# Sentence 40: I was hollow, a shell of who I’d been, wondering if I’d made the biggest mistake of my life.
# Sentence 41: Every day felt like a battle to just get out of bed, to go on with a life that suddenly felt like it wasn’t mine.
#
#
# Chunk 18:
# Sentence 42: And the worst part?
# Sentence 43: The memories.
#
#
# Chunk 19:
# Sentence 44: Everywhere I looked, I saw her—our inside jokes, her smile, the way she’d curl up next to me at night.
# Sentence 45: I felt haunted by a love that was still so painfully alive, yet completely out of reach.
# Sentence 46: I’ve spent the last two years trying to rebuild, piece by piece, but there’s a part of me that’s still living in that moment on the couch, holding her, crying, both of us knowing that what we had wasn’t strong enough to withstand the world.
#
#
# Chunk 20:
# Sentence 47: I still love her.
# Sentence 48: I don’t think that will ever change.
# Sentence 49: And I don’t know if I’ll ever truly move on.
#
#
# Chunk 21:
# Sentence 50: People say time heals, but some wounds feel too deep to ever really close.
# Sentence 51: I wanted to share this here, not because I’m looking for advice or sympathy, but because the weight of this loss is too much to carry alone.
# Sentence 52: I lost myself trying to make a life with her, and now, in letting go, I’m still trying to find the pieces of who I am without her.
#
#
# Chunk 22:
# Sentence 53: If you’re reading this, thank you.
#
#
# Chunk 23:
# Sentence 54: Sometimes, just putting it into words feels like the only way to make sense of it all.

# %%
from transformers import pipeline

# Load the emotion detection pipeline
emotion_detector = pipeline("text-classification", model="j-hartmann/emotion-english-distilroberta-base", top_k=None, device=device)

# %%
def analyze_emotions_in_chunk(chunk_text):
    # Get emotion scores from the pipeline
    results = emotion_detector(chunk_text)

    # Process results to get a dictionary of emotions and their scores
    emotions = {item['label']: item['score'] for item in results[0]}

    # Return the chunk text and its emotions
    return {
        "chunk": chunk_text,
        "emotions": emotions
    }

# %%
# Analyze emotions for each chunk individually
chunk_emotions = []

for chunk in final_chunks:
    # Join only the sentence texts to create a single text passage for emotion detection
    chunk_text = " ".join(sentence for _, sentence in chunk)

    # Run emotion analysis on the joined text passage
    analysis_result = analyze_emotions_in_chunk(chunk_text)

    # Store only the 
    # irst and last indices of the sentences in this chunk
    start_index = chunk[0][0]
    end_index = chunk[-1][0]

    # Add the text, emotion analysis, and index range to the result
    analysis_result["start_index"] = start_index
    analysis_result["end_index"] = end_index
    chunk_emotions.append(analysis_result)

# Display results
for i, result in enumerate(chunk_emotions):
    print(f"Chunk {i + 1}:")
    print(f"Text: {result['chunk']}")
    print(f"Sentence Indices in Original Text: {result['start_index']} to {result['end_index']}")
    print("Emotions:")
    for emotion, score in result['emotions'].items():
        print(f"  {emotion}: {score:.3f}")
    print("\n")
# Out:
# Chunk 1:
# Text: Two years ago, I made the hardest, most soul-shattering decision of my life: I left my wife. Not because I stopped loving her or because we grew apart. I walked away because I couldn’t keep tearing myself apart, trying to be someone I wasn’t, to fit into a life that felt like it was slowly strangling me.
# Sentence Indices in Original Text: 0 to 2
# Emotions:
#   sadness: 0.693
#   fear: 0.214
#   anger: 0.044
#   disgust: 0.026
#   neutral: 0.017
#   joy: 0.003
#   surprise: 0.002
#
#
# Chunk 2:
# Text: My ex-wife
# Sentence Indices in Original Text: 3 to 3
# Emotions:
#   sadness: 0.968
#   anger: 0.010
#   disgust: 0.007
#   surprise: 0.006
#   joy: 0.004
#   neutral: 0.004
#   fear: 0.001
#
#
# Chunk 3:
# Text: and I met when we were just kids, barely 18, with the kind of naive hope that thinks love can conquer anything. She was my best friend, my other half, my safe place in a world that sometimes felt too big and too cold. When we stood there exchanging vows, I truly believed we’d be together forever.
# Sentence Indices in Original Text: 4 to 6
# Emotions:
#   joy: 0.631
#   anger: 0.164
#   fear: 0.092
#   neutral: 0.046
#   sadness: 0.043
#   surprise: 0.020
#   disgust: 0.004
#
#
# Chunk 4:
# Text: And maybe we could have been—if it was just us. But it wasn’t.
# Sentence Indices in Original Text: 7 to 8
# Emotions:
#   neutral: 0.779
#   surprise: 0.092
#   sadness: 0.045
#   disgust: 0.029
#   anger: 0.028
#   fear: 0.022
#   joy: 0.006
#
#
# Chunk 5:
# Text: Her family had expectations.
# Sentence Indices in Original Text: 9 to 9
# Emotions:
#   neutral: 0.796
#   disgust: 0.091
#   anger: 0.075
#   surprise: 0.018
#   sadness: 0.014
#   joy: 0.004
#   fear: 0.002
#
#
# Chunk 6:
# Text: They wanted a doctor, a respected man with a title and prestige, someone who fit into their perfect image of success.
# Sentence Indices in Original Text: 10 to 10
# Emotions:
#   neutral: 0.935
#   disgust: 0.017
#   joy: 0.017
#   surprise: 0.014
#   anger: 0.009
#   sadness: 0.006
#   fear: 0.001
#
#
# Chunk 7:
# Text: They never said it outright, but every look, every subtle comment chipped away at me. They didn’t see me for who I was—they only saw the gap between who I was and who they thought I should be. And my wife…she was caught in the middle, torn between their love and mine.
# Sentence Indices in Original Text: 11 to 13
# Emotions:
#   disgust: 0.335
#   neutral: 0.283
#   anger: 0.121
#   surprise: 0.115
#   fear: 0.093
#   sadness: 0.048
#   joy: 0.004
#
#
# Chunk 8:
# Text: We tried to make it work. God, we tried everything.
# Sentence Indices in Original Text: 14 to 15
# Emotions:
#   anger: 0.415
#   disgust: 0.296
#   surprise: 0.155
#   neutral: 0.076
#   sadness: 0.030
#   fear: 0.019
#   joy: 0.008
#
#
# Chunk 9:
# Text: We moved to different cities, created distance from her family, hoping that it would give us space to build something that was just ours. For a while, it worked, and I thought maybe we’d found a way.
# Sentence Indices in Original Text: 16 to 17
# Emotions:
#   neutral: 0.922
#   joy: 0.030
#   surprise: 0.016
#   disgust: 0.012
#   anger: 0.010
#   sadness: 0.007
#   fear: 0.003
#
#
# Chunk 10:
# Text: But every holiday, every phone call brought those expectations crashing back down on us. It was like her family’s hopes for her future were this invisible weight pressing down on us, one I couldn’t shake no matter how hard I tried.
# Sentence Indices in Original Text: 18 to 19
# Emotions:
#   fear: 0.918
#   surprise: 0.057
#   neutral: 0.011
#   anger: 0.005
#   disgust: 0.003
#   sadness: 0.003
#   joy: 0.002
#
#
# Chunk 11:
# Text: My wife started to change. She didn’t want to, I could see that. But that constant tension wore on her.
# Sentence Indices in Original Text: 20 to 22
# Emotions:
#   disgust: 0.520
#   anger: 0.179
#   neutral: 0.133
#   fear: 0.112
#   sadness: 0.044
#   surprise: 0.008
#   joy: 0.004
#
#
# Chunk 12:
# Text: She looked at me like she was caught in a trap, like she was torn in two.
# Sentence Indices in Original Text: 23 to 23
# Emotions:
#   disgust: 0.621
#   neutral: 0.210
#   fear: 0.068
#   anger: 0.045
#   surprise: 0.039
#   sadness: 0.015
#   joy: 0.001
#
#
# Chunk 13:
# Text: And I felt powerless.
# Sentence Indices in Original Text: 24 to 24
# Emotions:
#   fear: 0.693
#   sadness: 0.233
#   disgust: 0.032
#   neutral: 0.027
#   anger: 0.006
#   joy: 0.006
#   surprise: 0.003
#
#
# Chunk 14:
# Text: I couldn’t ask her to choose, but I could see the pain she felt, the guilt she carried. Her family had her in their grip, and I was just another weight, pulling her in the opposite direction.
# Sentence Indices in Original Text: 25 to 26
# Emotions:
#   sadness: 0.467
#   disgust: 0.244
#   neutral: 0.227
#   anger: 0.041
#   fear: 0.014
#   surprise: 0.004
#   joy: 0.003
#
#
# Chunk 15:
# Text: Eventually, we both broke. I remember the day we decided to separate.
# Sentence Indices in Original Text: 27 to 28
# Emotions:
#   sadness: 0.896
#   neutral: 0.041
#   disgust: 0.032
#   anger: 0.014
#   fear: 0.011
#   joy: 0.005
#   surprise: 0.002
#
#
# Chunk 16:
# Text: There wasn’t yelling or accusations, no one stormed out. It was quiet, like a mutual surrender.
# Sentence Indices in Original Text: 29 to 30
# Emotions:
#   neutral: 0.788
#   anger: 0.109
#   disgust: 0.060
#   fear: 0.022
#   sadness: 0.012
#   joy: 0.005
#   surprise: 0.004
#
#
# Chunk 17:
# Text: We sat on the couch, both of us just holding each other, crying, knowing that love wasn’t enough to save us from the world around us. And in that moment, I felt like my heart was being torn out of my chest. I let go of the one person who knew me inside and out, not because I wanted to, but because I felt like I was suffocating. I thought that maybe, if I wasn’t in her life, she’d finally be free to live without that constant push and pull, free from the guilt and the expectations that haunted us. I thought I was doing something selfless, but the truth? I was broken. Walking away shattered me in ways I didn’t know were possible. In the months after, I barely recognized myself. I was hollow, a shell of who I’d been, wondering if I’d made the biggest mistake of my life. Every day felt like a battle to just get out of bed, to go on with a life that suddenly felt like it wasn’t mine.
# Sentence Indices in Original Text: 31 to 40
# Emotions:
#   fear: 0.673
#   sadness: 0.272
#   neutral: 0.019
#   surprise: 0.016
#   disgust: 0.013
#   anger: 0.005
#   joy: 0.001
#
#
# Chunk 18:
# Text: And the worst part? The memories.
# Sentence Indices in Original Text: 41 to 42
# Emotions:
#   disgust: 0.987
#   anger: 0.006
#   neutral: 0.002
#   sadness: 0.002
#   fear: 0.002
#   surprise: 0.000
#   joy: 0.000
#
#
# Chunk 19:
# Text: Everywhere I looked, I saw her—our inside jokes, her smile, the way she’d curl up next to me at night. I felt haunted by a love that was still so painfully alive, yet completely out of reach. I’ve spent the last two years trying to rebuild, piece by piece, but there’s a part of me that’s still living in that moment on the couch, holding her, crying, both of us knowing that what we had wasn’t strong enough to withstand the world.
# Sentence Indices in Original Text: 43 to 45
# Emotions:
#   fear: 0.963
#   sadness: 0.012
#   neutral: 0.011
#   surprise: 0.007
#   disgust: 0.006
#   anger: 0.001
#   joy: 0.001
#
#
# Chunk 20:
# Text: I still love her. I don’t think that will ever change. And I don’t know if I’ll ever truly move on.
# Sentence Indices in Original Text: 46 to 48
# Emotions:
#   neutral: 0.702
#   sadness: 0.130
#   joy: 0.060
#   disgust: 0.036
#   fear: 0.033
#   surprise: 0.029
#   anger: 0.009
#
#
# Chunk 21:
# Text: People say time heals, but some wounds feel too deep to ever really close. I wanted to share this here, not because I’m looking for advice or sympathy, but because the weight of this loss is too much to carry alone. I lost myself trying to make a life with her, and now, in letting go, I’m still trying to find the pieces of who I am without her.
# Sentence Indices in Original Text: 49 to 51
# Emotions:
#   sadness: 0.944
#   neutral: 0.031
#   disgust: 0.011
#   fear: 0.007
#   surprise: 0.003
#   anger: 0.002
#   joy: 0.002
#
#
# Chunk 22:
# Text: If you’re reading this, thank you.
# Sentence Indices in Original Text: 52 to 52
# Emotions:
#   neutral: 0.543
#   joy: 0.356
#   surprise: 0.043
#   anger: 0.034
#   disgust: 0.018
#   sadness: 0.004
#   fear: 0.002
#
#
# Chunk 23:
# Text: Sometimes, just putting it into words feels like the only way to make sense of it all.
# Sentence Indices in Original Text: 53 to 53
# Emotions:
#   neutral: 0.910
#   disgust: 0.046
#   joy: 0.014
#   surprise: 0.013
#   anger: 0.011
#   sadness: 0.004
#   fear: 0.002

# %%
chunk_emotions
# Out:
# [{'chunk': 'Two years ago, I made the hardest, most soul-shattering decision of my life: I left my wife. Not because I stopped loving her or because we grew apart. I walked away because I couldn’t keep tearing myself apart, trying to be someone I wasn’t, to fit into a life that felt like it was slowly strangling me.',
#   'emotions': {'sadness': 0.6933683753013611,
#    'fear': 0.21393989026546478,
#    'anger': 0.04419312626123428,
#    'disgust': 0.026415416970849037,
#    'neutral': 0.016583560034632683,
#    'joy': 0.0032139967661350965,
#    'surprise': 0.002285611815750599},
#   'start_index': 0,
#   'end_index': 2},
#  {'chunk': 'My ex-wife',
#   'emotions': {'sadness': 0.9677837491035461,
#    'anger': 0.009964397177100182,
#    'disgust': 0.00702268909662962,
#    'surprise': 0.006057017482817173,
#    'joy': 0.004129399079829454,
#    'neutral': 0.003566598054021597,
#    'fear': 0.0014762701466679573},
#   'start_index': 3,
#   'end_index': 3},
#  {'chunk': 'and I met when we were just kids, barely 18, with the kind of naive hope that thinks love can conquer anything. She was my best friend, my other half, my safe place in a world that sometimes felt too big and too cold. When we stood there exchanging vows, I truly believed we’d be together forever.',
#   'emotions': {'joy': 0.6311129927635193,
#    'anger': 0.1637718677520752,
#    'fear': 0.09236039966344833,
#    'neutral': 0.04588460549712181,
#    'sadness': 0.043012529611587524,
#    'surprise': 0.020065484568476677,
#    'disgust': 0.00379207287915051},
#   'start_index': 4,
#   'end_index': 6},
#  {'chunk': 'And maybe we could have been—if it was just us. But it wasn’t.',
#   'emotions': {'neutral': 0.77886563539505,
#    'surprise': 0.0917145311832428,
#    'sadness': 0.04542654752731323,
#    'disgust': 0.02862664870917797,
#    'anger': 0.027515443041920662,
#    'fear': 0.021906813606619835,
#    'joy': 0.005944351200014353},
#   'start_index': 7,
#   'end_index': 8},
#  {'chunk': 'Her family had expectations.',
#   'emotions': {'neutral': 0.7964175343513489,
#    'disgust': 0.09094103425741196,
#    'anger': 0.0747646689414978,
#    'surprise': 0.01752469688653946,
#    'sadness': 0.013750012032687664,
#    'joy': 0.0041470094583928585,
#    'fear': 0.0024550401140004396},
#   'start_index': 9,
#   'end_index': 9},
#  {'chunk': 'They wanted a doctor, a respected man with a title and prestige, someone who fit into their perfect image of success.',
#   'emotions': {'neutral': 0.9353101849555969,
#    'disgust': 0.017065539956092834,
#    'joy': 0.01703820191323757,
#    'surprise': 0.014442595653235912,
#    'anger': 0.009322801604866982,
#    'sadness': 0.005721453111618757,
#    'fear': 0.0010991650633513927},
#   'start_index': 10,
#   'end_index': 10},
#  {'chunk': 'They never said it outright, but every look, every subtle comment chipped away at me. They didn’t see me for who I was—they only saw the gap between who I was and who they thought I should be. And my wife…she was caught in the middle, torn between their love and mine.',
#   'emotions': {'disgust': 0.3354030251502991,
#    'neutral': 0.28342798352241516,
#    'anger': 0.12081153690814972,
#    'surprise': 0.11479740589857101,
#    'fear': 0.09347665309906006,
#    'sadness': 0.048170629888772964,
#    'joy': 0.003912707790732384},
#   'start_index': 11,
#   'end_index': 13},
#  {'chunk': 'We tried to make it work. God, we tried everything.',
#   'emotions': {'anger': 0.41457095742225647,
#    'disgust': 0.2961852252483368,
#    'surprise': 0.1554538756608963,
#    'neutral': 0.07638655602931976,
#    'sadness': 0.030125895515084267,
#    'fear': 0.0193413607776165,
#    'joy': 0.007936249487102032},
#   'start_index': 14,
#   'end_index': 15},
#  {'chunk': 'We moved to different cities, created distance from her family, hoping that it would give us space to build something that was just ours. For a while, it worked, and I thought maybe we’d found a way.',
#   'emotions': {'neutral': 0.922128438949585,
#    'joy': 0.03034074418246746,
#    'surprise': 0.015683487057685852,
#    'disgust': 0.01158841047435999,
#    'anger': 0.010461532510817051,
#    'sadness': 0.006897273473441601,
#    'fear': 0.002899994608014822},
#   'start_index': 16,
#   'end_index': 17},
#  {'chunk': 'But every holiday, every phone call brought those expectations crashing back down on us. It was like her family’s hopes for her future were this invisible weight pressing down on us, one I couldn’t shake no matter how hard I tried.',
#   'emotions': {'fear': 0.918432891368866,
#    'surprise': 0.05653287097811699,
#    'neutral': 0.010990912094712257,
#    'anger': 0.005428519565612078,
#    'disgust': 0.003408087883144617,
#    'sadness': 0.0028366881888359785,
#    'joy': 0.002370065776631236},
#   'start_index': 18,
#   'end_index': 19},
#  {'chunk': 'My wife started to change. She didn’t want to, I could see that. But that constant tension wore on her.',
#   'emotions': {'disgust': 0.5203697085380554,
#    'anger': 0.178824782371521,
#    'neutral': 0.13306541740894318,
#    'fear': 0.11246242374181747,
#    'sadness': 0.043508101254701614,
#    'surprise': 0.0076856971718370914,
#    'joy': 0.004083846230059862},
#   'start_index': 20,
#   'end_index': 22},
#  {'chunk': 'She looked at me like she was caught in a trap, like she was torn in two.',
#   'emotions': {'disgust': 0.6213771104812622,
#    'neutral': 0.21038274466991425,
#    'fear': 0.06842099130153656,
#    'anger': 0.0445312075316906,
#    'surprise': 0.03874269500374794,
#    'sadness': 0.015243999660015106,
#    'joy': 0.0013012957060709596},
#   'start_index': 23,
#   'end_index': 23},
#  {'chunk': 'And I felt powerless.',
#   'emotions': {'fear': 0.6928602457046509,
#    'sadness': 0.23294615745544434,
#    'disgust': 0.03206668421626091,
#    'neutral': 0.026874631643295288,
#    'anger': 0.006197067908942699,
#    'joy': 0.006062456406652927,
#    'surprise': 0.0029928735457360744},
#   'start_index': 24,
#   'end_index': 24},
#  {'chunk': 'I couldn’t ask her to choose, but I could see the pain she felt, the guilt she carried. Her family had her in their grip, and I was just another weight, pulling her in the opposite direction.',
#   'emotions': {'sadness': 0.46668440103530884,
#    'disgust': 0.2435440570116043,
#    'neutral': 0.22719015181064606,
#    'anger': 0.04101768508553505,
#    'fear': 0.01442133542150259,
#    'surprise': 0.0039861383847892284,
#    'joy': 0.0031563262455165386},
#   'start_index': 25,
#   'end_index': 26},
#  {'chunk': 'Eventually, we both broke. I remember the day we decided to separate.',
#   'emotions': {'sadness': 0.8960078358650208,
#    'neutral': 0.04051469266414642,
#    'disgust': 0.031974006444215775,
#    'anger': 0.013523862697184086,
#    'fear': 0.010632848367094994,
#    'joy': 0.004976615309715271,
#    'surprise': 0.002370184287428856},
#   'start_index': 27,
#   'end_index': 28},
#  {'chunk': 'There wasn’t yelling or accusations, no one stormed out. It was quiet, like a mutual surrender.',
#   'emotions': {'neutral': 0.7878429293632507,
#    'anger': 0.10910331457853317,
#    'disgust': 0.060084741562604904,
#    'fear': 0.021982412785291672,
#    'sadness': 0.012007946148514748,
#    'joy': 0.005031501408666372,
#    'surprise': 0.003947181161493063},
#   'start_index': 29,
#   'end_index': 30},
#  {'chunk': 'We sat on the couch, both of us just holding each other, crying, knowing that love wasn’t enough to save us from the world around us. And in that moment, I felt like my heart was being torn out of my chest. I let go of the one person who knew me inside and out, not because I wanted to, but because I felt like I was suffocating. I thought that maybe, if I wasn’t in her life, she’d finally be free to live without that constant push and pull, free from the guilt and the expectations that haunted us. I thought I was doing something selfless, but the truth? I was broken. Walking away shattered me in ways I didn’t know were possible. In the months after, I barely recognized myself. I was hollow, a shell of who I’d been, wondering if I’d made the biggest mistake of my life. Every day felt like a battle to just get out of bed, to go on with a life that suddenly felt like it wasn’t mine.',
#   'emotions': {'fear': 0.6733574271202087,
#    'sadness': 0.2716792821884155,
#    'neutral': 0.018860068172216415,
#    'surprise': 0.01572633720934391,
#    'disgust': 0.013495953753590584,
#    'anger': 0.005392019636929035,
#    'joy': 0.0014888743171468377},
#   'start_index': 31,
#   'end_index': 40},
#  {'chunk': 'And the worst part? The memories.',
#   'emotions': {'disgust': 0.9872612953186035,
#    'anger': 0.005686618387699127,
#    'neutral': 0.002310435986146331,
#    'sadness': 0.0021291119046509266,
#    'fear': 0.001831253175623715,
#    'surprise': 0.00043000892037525773,
#    'joy': 0.00035134496283717453},
#   'start_index': 41,
#   'end_index': 42},
#  {'chunk': 'Everywhere I looked, I saw her—our inside jokes, her smile, the way she’d curl up next to me at night. I felt haunted by a love that was still so painfully alive, yet completely out of reach. I’ve spent the last two years trying to rebuild, piece by piece, but there’s a part of me that’s still living in that moment on the couch, holding her, crying, both of us knowing that what we had wasn’t strong enough to withstand the world.',
#   'emotions': {'fear': 0.9625272750854492,
#    'sadness': 0.011871526017785072,
#    'neutral': 0.01104142889380455,
#    'surprise': 0.006868314929306507,
#    'disgust': 0.00581716513261199,
#    'anger': 0.0011431945022195578,
#    'joy': 0.0007309992797672749},
#   'start_index': 43,
#   'end_index': 45},
#  {'chunk': 'I still love her. I don’t think that will ever change. And I don’t know if I’ll ever truly move on.',
#   'emotions': {'neutral': 0.7018812298774719,
#    'sadness': 0.1304495632648468,
#    'joy': 0.06004450470209122,
#    'disgust': 0.03639984503388405,
#    'fear': 0.032793041318655014,
#    'surprise': 0.029451005160808563,
#    'anger': 0.008980759419500828},
#   'start_index': 46,
#   'end_index': 48},
#  {'chunk': 'People say time heals, but some wounds feel too deep to ever really close. I wanted to share this here, not because I’m looking for advice or sympathy, but because the weight of this loss is too much to carry alone. I lost myself trying to make a life with her, and now, in letting go, I’m still trying to find the pieces of who I am without her.',
#   'emotions': {'sadness': 0.9443084001541138,
#    'neutral': 0.031350668519735336,
#    'disgust': 0.010710736736655235,
#    'fear': 0.006819377653300762,
#    'surprise': 0.002821768634021282,
#    'anger': 0.0024229236878454685,
#    'joy': 0.0015660481294617057},
#   'start_index': 49,
#   'end_index': 51},
#  {'chunk': 'If you’re reading this, thank you.',
#   'emotions': {'neutral': 0.5433110594749451,
#    'joy': 0.35562288761138916,
#    'surprise': 0.043314915150403976,
#    'anger': 0.03412208706140518,
#    'disgust': 0.018331153318285942,
#    'sadness': 0.0035707030910998583,
#    'fear': 0.0017271387623623013},
#   'start_index': 52,
#   'end_index': 52},
#  {'chunk': 'Sometimes, just putting it into words feels like the only way to make sense of it all.',
#   'emotions': {'neutral': 0.9103854298591614,
#    'disgust': 0.046296168118715286,
#    'joy': 0.01418670266866684,
#    'surprise': 0.012762476690113544,
#    'anger': 0.010651621036231518,
#    'sadness': 0.003637752728536725,
#    'fear': 0.002079860307276249},
#   'start_index': 53,
#   'end_index': 53}]

# %%
for chunk in chunk_emotions:
  first_sentence = sentences[chunk['start_index']]
  last_sentence = sentences[chunk['end_index']]
  print(f"{first_sentence.start_char} - {last_sentence.end_char}")
  print(" Emotions:")
  for emotion, score in chunk['emotions'].items():
    print(f"  {emotion}: {score:.3f}")
  print()
# Out:
# 0 - 307
#  Emotions:
#   sadness: 0.693
#   fear: 0.214
#   anger: 0.044
#   disgust: 0.026
#   neutral: 0.017
#   joy: 0.003
#   surprise: 0.002
#
# 307 - 317
#  Emotions:
#   sadness: 0.968
#   anger: 0.010
#   disgust: 0.007
#   surprise: 0.006
#   joy: 0.004
#   neutral: 0.004
#   fear: 0.001
#
# 318 - 615
#  Emotions:
#   joy: 0.631
#   anger: 0.164
#   fear: 0.092
#   neutral: 0.046
#   sadness: 0.043
#   surprise: 0.020
#   disgust: 0.004
#
# 616 - 680
#  Emotions:
#   neutral: 0.779
#   surprise: 0.092
#   sadness: 0.045
#   disgust: 0.029
#   anger: 0.028
#   fear: 0.022
#   joy: 0.006
#
# 680 - 708
#  Emotions:
#   neutral: 0.796
#   disgust: 0.091
#   anger: 0.075
#   surprise: 0.018
#   sadness: 0.014
#   joy: 0.004
#   fear: 0.002
#
# 709 - 826
#  Emotions:
#   neutral: 0.935
#   disgust: 0.017
#   joy: 0.017
#   surprise: 0.014
#   anger: 0.009
#   sadness: 0.006
#   fear: 0.001
#
# 827 - 1097
#  Emotions:
#   disgust: 0.335
#   neutral: 0.283
#   anger: 0.121
#   surprise: 0.115
#   fear: 0.093
#   sadness: 0.048
#   joy: 0.004
#
# 1097 - 1148
#  Emotions:
#   anger: 0.415
#   disgust: 0.296
#   surprise: 0.155
#   neutral: 0.076
#   sadness: 0.030
#   fear: 0.019
#   joy: 0.008
#
# 1149 - 1348
#  Emotions:
#   neutral: 0.922
#   joy: 0.030
#   surprise: 0.016
#   disgust: 0.012
#   anger: 0.010
#   sadness: 0.007
#   fear: 0.003
#
# 1349 - 1582
#  Emotions:
#   fear: 0.918
#   surprise: 0.057
#   neutral: 0.011
#   anger: 0.005
#   disgust: 0.003
#   sadness: 0.003
#   joy: 0.002
#
# 1582 - 1685
#  Emotions:
#   disgust: 0.520
#   anger: 0.179
#   neutral: 0.133
#   fear: 0.112
#   sadness: 0.044
#   surprise: 0.008
#   joy: 0.004
#
# 1686 - 1759
#  Emotions:
#   disgust: 0.621
#   neutral: 0.210
#   fear: 0.068
#   anger: 0.045
#   surprise: 0.039
#   sadness: 0.015
#   joy: 0.001
#
# 1760 - 1781
#  Emotions:
#   fear: 0.693
#   sadness: 0.233
#   disgust: 0.032
#   neutral: 0.027
#   anger: 0.006
#   joy: 0.006
#   surprise: 0.003
#
# 1782 - 1975
#  Emotions:
#   sadness: 0.467
#   disgust: 0.244
#   neutral: 0.227
#   anger: 0.041
#   fear: 0.014
#   surprise: 0.004
#   joy: 0.003
#
# 1975 - 2044
#  Emotions:
#   sadness: 0.896
#   neutral: 0.041
#   disgust: 0.032
#   anger: 0.014
#   fear: 0.011
#   joy: 0.005
#   surprise: 0.002
#
# 2045 - 2140
#  Emotions:
#   neutral: 0.788
#   anger: 0.109
#   disgust: 0.060
#   fear: 0.022
#   sadness: 0.012
#   joy: 0.005
#   surprise: 0.004
#
# 2141 - 3034
#  Emotions:
#   fear: 0.673
#   sadness: 0.272
#   neutral: 0.019
#   surprise: 0.016
#   disgust: 0.013
#   anger: 0.005
#   joy: 0.001
#
# 3035 - 3068
#  Emotions:
#   disgust: 0.987
#   anger: 0.006
#   neutral: 0.002
#   sadness: 0.002
#   fear: 0.002
#   surprise: 0.000
#   joy: 0.000
#
# 3069 - 3502
#  Emotions:
#   fear: 0.963
#   sadness: 0.012
#   neutral: 0.011
#   surprise: 0.007
#   disgust: 0.006
#   anger: 0.001
#   joy: 0.001
#
# 3503 - 3604
#  Emotions:
#   neutral: 0.702
#   sadness: 0.130
#   joy: 0.060
#   disgust: 0.036
#   fear: 0.033
#   surprise: 0.029
#   anger: 0.009
#
# 3604 - 3952
#  Emotions:
#   sadness: 0.944
#   neutral: 0.031
#   disgust: 0.011
#   fear: 0.007
#   surprise: 0.003
#   anger: 0.002
#   joy: 0.002
#
# 3952 - 3986
#  Emotions:
#   neutral: 0.543
#   joy: 0.356
#   surprise: 0.043
#   anger: 0.034
#   disgust: 0.018
#   sadness: 0.004
#   fear: 0.002
#
# 3987 - 4073
#  Emotions:
#   neutral: 0.910
#   disgust: 0.046
#   joy: 0.014
#   surprise: 0.013
#   anger: 0.011
#   sadness: 0.004
#   fear: 0.002
